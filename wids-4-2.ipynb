# %%
# !pip install flwr==1.7.0 --no-deps

# %%
import numpy as np
if not hasattr(np, "float_"):
    np.float_ = np.float64

# %%
import numpy as np
if not hasattr(np, "float_"):
    np.float_ = np.float64
import flwr
print(flwr.__version__)

print("done")

# %%
# !pip install iterators

# %%
# !pip install flwr==1.9.0

# %%
# !pip install flwr==1.4.0

# %%
# !pip install tensorflow==2.17.0

# %%
# !pip install flwr==1.9.0 protobuf==4.25.3

# %%
import numpy as np

# Patch for NumPy 2.0 compatibility
if not hasattr(np, "float_"):
    np.float_ = np.float64

# %%
import flwr
import tensorflow as tf
import numpy as np

print("Flower:", flwr.__version__)
print("TensorFlow:", tf.__version__)
print("NumPy:", np.__version__)

# %%
# !pip install flwr==1.9.0 protobuf==4.25.3 tensorflow==2.17.0

# %%
import flwr
import tensorflow as tf
import numpy as np

print("Flower:", flwr.__version__)
print("TensorFlow:", tf.__version__)
print("NumPy:", np.__version__)

# %%
# !pip install jax==0.4.28 numpy==1.26.4

# %%
# !pip install flwr==1.9.0 protobuf==4.25.3 tensorflow==2.17.0 jax==0.7.2

# %%
# !pip install tensorflow==2.17.0 flwr==1.9.0 jax==0.4.28 ml-dtypes==0.4.1

# %%
import flwr
import tensorflow as tf
import numpy as np

print("Flower:", flwr.__version__)
print("TensorFlow:", tf.__version__)
print("NumPy:", np.__version__)

# %%
import flwr.simulation as fl_sim
print("Flower simulation available:", fl_sim)

# %%
# !pip uninstall -y flwr
# !pip install flwr-nightly

# %%
# !pip install protobuf==4.25.3 --force-reinstall

# %%
# !pip install --force-reinstall tensorflow==2.17.0 flwr==1.9.0 protobuf==4.25.3

# %%
import flwr
import tensorflow as tf
import numpy as np

print("Flower:", flwr.__version__)
print("TensorFlow:", tf.__version__)
print("NumPy:", np.__version__)

# %%
import numpy as np

# Patch for NumPy 2.0 compatibility
if not hasattr(np, "float_"):
    np.float_ = np.float64
    
import flwr
print(flwr.__version__)

print("done")

# %%
# !pip install --force-reinstall jax==0.4.28 jaxlib==0.4.28

# %%
# !pip install --force-reinstall numpy==1.26.4 ml-dtypes==0.4.1

# %%
import jax
import flwr
import tensorflow as tf
import numpy as np

print("JAX:", jax.__version__)
print("Flower:", flwr.__version__)
print("TensorFlow:", tf.__version__)
print("NumPy:", np.__version__)

# %%
import flwr.client as fl_client
import flwr.simulation as fl_sim
import tensorflow as tf
import numpy as np

print("Flower:", fl_client.__package__)
print("TensorFlow:", tf.__version__)
print("NumPy:", np.__version__)

# %%
---------------------------------------------------------------------------
AttributeError                            Traceback (most recent call last)
/tmp/ipykernel_55/676540566.py in <cell line: 0>()
----> 1 import flwr.client as fl_client
      2 import flwr.simulation as fl_sim
      3 import tensorflow as tf
      4 import numpy as np
      5 

/usr/local/lib/python3.12/dist-packages/flwr/__init__.py in <module>
     18 from flwr.common.version import package_version as _package_version
     19 
---> 20 from . import client, common, server, simulation
     21 
     22 __all__ = [

/usr/local/lib/python3.12/dist-packages/flwr/server/__init__.py in <module>
     17 
     18 from . import strategy
---> 19 from . import workflow as workflow
     20 from .app import run_driver_api as run_driver_api
     21 from .app import run_fleet_api as run_fleet_api

/usr/local/lib/python3.12/dist-packages/flwr/server/workflow/__init__.py in <module>
     16 
     17 
---> 18 from .default_workflows import DefaultWorkflow
     19 from .secure_aggregation import SecAggPlusWorkflow, SecAggWorkflow
     20 

/usr/local/lib/python3.12/dist-packages/flwr/server/workflow/default_workflows.py in <module>
     35 
     36 from ..client_proxy import ClientProxy
---> 37 from ..compat.app_utils import start_update_client_manager_thread
     38 from ..compat.legacy_context import LegacyContext
     39 from ..driver import Driver

/usr/local/lib/python3.12/dist-packages/flwr/server/compat/__init__.py in <module>
     16 
     17 
---> 18 from .app import start_driver as start_driver
     19 from .legacy_context import LegacyContext as LegacyContext
     20 

/usr/local/lib/python3.12/dist-packages/flwr/server/compat/app.py in <module>
     27 from flwr.server.strategy import Strategy
     28 
---> 29 from ..driver import Driver
     30 from .app_utils import start_update_client_manager_thread
     31 

/usr/local/lib/python3.12/dist-packages/flwr/server/driver/__init__.py in <module>
     18 from .driver import Driver
     19 from .grpc_driver import GrpcDriver
---> 20 from .inmemory_driver import InMemoryDriver
     21 
     22 __all__ = [

/usr/local/lib/python3.12/dist-packages/flwr/server/driver/inmemory_driver.py in <module>
     24 from flwr.common.serde import message_from_taskres, message_to_taskins
     25 from flwr.proto.node_pb2 import Node  # pylint: disable=E0611
---> 26 from flwr.server.superlink.state import StateFactory
     27 
     28 from .driver import Driver

/usr/local/lib/python3.12/dist-packages/flwr/server/superlink/state/__init__.py in <module>
     16 
     17 
---> 18 from .in_memory_state import InMemoryState as InMemoryState
     19 from .sqlite_state import SqliteState as SqliteState
     20 from .state import State as State

/usr/local/lib/python3.12/dist-packages/flwr/server/superlink/state/in_memory_state.py in <module>
     26 from flwr.proto.task_pb2 import TaskIns, TaskRes  # pylint: disable=E0611
     27 from flwr.server.superlink.state.state import State
---> 28 from flwr.server.utils import validate_task_ins_or_res
     29 
     30 from .utils import make_node_unavailable_taskres

/usr/local/lib/python3.12/dist-packages/flwr/server/utils/__init__.py in <module>
     16 
     17 
---> 18 from .tensorboard import tensorboard as tensorboard
     19 from .validator import validate_task_ins_or_res as validate_task_ins_or_res
     20 

/usr/local/lib/python3.12/dist-packages/flwr/server/utils/tensorboard.py in <module>
     27 
     28 try:
---> 29     import tensorflow as TF
     30 except ModuleNotFoundError:
     31     TF = None

/usr/local/lib/python3.12/dist-packages/tensorflow/__init__.py in <module>
     51 from tensorflow._api.v2 import autograph
     52 from tensorflow._api.v2 import bitwise
---> 53 from tensorflow._api.v2 import compat
     54 from tensorflow._api.v2 import config
     55 from tensorflow._api.v2 import data

/usr/local/lib/python3.12/dist-packages/tensorflow/_api/v2/compat/__init__.py in <module>
      6 import sys as _sys
      7 
----> 8 from tensorflow._api.v2.compat import v1
      9 from tensorflow._api.v2.compat import v2
     10 from tensorflow.python.compat.compat import forward_compatibility_horizon # line: 125

/usr/local/lib/python3.12/dist-packages/tensorflow/_api/v2/compat/v1/__init__.py in <module>
     28 from tensorflow._api.v2.compat.v1 import autograph
     29 from tensorflow._api.v2.compat.v1 import bitwise
---> 30 from tensorflow._api.v2.compat.v1 import compat
     31 from tensorflow._api.v2.compat.v1 import config
     32 from tensorflow._api.v2.compat.v1 import data

/usr/local/lib/python3.12/dist-packages/tensorflow/_api/v2/compat/v1/compat/__init__.py in <module>
      6 import sys as _sys
      7 
----> 8 from tensorflow._api.v2.compat.v1.compat import v1
      9 from tensorflow._api.v2.compat.v1.compat import v2
     10 from tensorflow.python.compat.compat import forward_compatibility_horizon # line: 125

/usr/local/lib/python3.12/dist-packages/tensorflow/_api/v2/compat/v1/compat/v1/__init__.py in <module>
     45 from tensorflow._api.v2.compat.v1 import layers
     46 from tensorflow._api.v2.compat.v1 import linalg
---> 47 from tensorflow._api.v2.compat.v1 import lite
     48 from tensorflow._api.v2.compat.v1 import logging
     49 from tensorflow._api.v2.compat.v1 import lookup

/usr/local/lib/python3.12/dist-packages/tensorflow/_api/v2/compat/v1/lite/__init__.py in <module>
      7 
      8 from tensorflow._api.v2.compat.v1.lite import constants
----> 9 from tensorflow._api.v2.compat.v1.lite import experimental
     10 from tensorflow.lite.python.convert import OpsSet # line: 170
     11 from tensorflow.lite.python.convert import toco_convert # line: 1069

/usr/local/lib/python3.12/dist-packages/tensorflow/_api/v2/compat/v1/lite/experimental/__init__.py in <module>
      6 import sys as _sys
      7 
----> 8 from tensorflow._api.v2.compat.v1.lite.experimental import authoring
      9 from tensorflow.lite.python.analyzer import ModelAnalyzer as Analyzer # line: 35
     10 from tensorflow.lite.python.interpreter import OpResolverType # line: 303

/usr/local/lib/python3.12/dist-packages/tensorflow/_api/v2/compat/v1/lite/experimental/authoring/__init__.py in <module>
      6 import sys as _sys
      7 
----> 8 from tensorflow.lite.python.authoring.authoring import compatible # line: 265
      9 
     10 from tensorflow.python.util import module_wrapper as _module_wrapper

/usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/authoring/authoring.py in <module>
     41 
     42 # pylint: disable=g-import-not-at-top
---> 43 from tensorflow.lite.python import convert
     44 from tensorflow.lite.python import lite
     45 from tensorflow.lite.python.metrics import converter_error_data_pb2

/usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py in <module>
     29 from tensorflow.compiler.mlir.quantization.stablehlo import quantization_options_pb2 as quant_opts_pb2
     30 from tensorflow.lite.python import lite_constants
---> 31 from tensorflow.lite.python import util
     32 from tensorflow.lite.python.convert_phase import Component
     33 from tensorflow.lite.python.convert_phase import convert_phase

/usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/util.py in <module>
     53 # pylint: disable=unused-import
     54 try:
---> 55   from jax import xla_computation as _xla_computation
     56 except ImportError:
     57   _xla_computation = None

/usr/local/lib/python3.12/dist-packages/jax/__init__.py in <module>
     35 
     36 # Force early import, allowing use of `jax.core` after importing `jax`.
---> 37 import jax.core as _core
     38 del _core
     39 

/usr/local/lib/python3.12/dist-packages/jax/core.py in <module>
     16 # See PEP 484 & https://github.com/google/jax/issues/7570
     17 
---> 18 from jax._src.core import (
     19   AbstractToken as AbstractToken,
     20   AbstractValue as AbstractValue,

/usr/local/lib/python3.12/dist-packages/jax/_src/core.py in <module>
     45 from jax._src import linear_util as lu
     46 
---> 47 from jax._src import source_info_util
     48 from jax._src.util import (safe_zip, safe_map, curry, tuple_insert,
     49                            tuple_delete, as_hashable_function,

/usr/local/lib/python3.12/dist-packages/jax/_src/source_info_util.py in <module>
     49     # Attach the separator to make sure that .../jax does not end up matching
     50     # .../jax_triton and other packages that might have a jax prefix.
---> 51     os.path.dirname(jax.version.__file__) + os.sep,
     52     # Also exclude stdlib as user frames. In a non-standard Python runtime,
     53     # the following two may be different.

AttributeError: partially initialized module 'jax' has no attribute 'version' (most likely due to a circular import)

# %%
---------------------------------------------------------------------------
AttributeError                            Traceback (most recent call last)
/tmp/ipykernel_55/676540566.py in <cell line: 0>()
----> 1 import flwr.client as fl_client
      2 import flwr.simulation as fl_sim
      3 import tensorflow as tf
      4 import numpy as np
      5 

/usr/local/lib/python3.12/dist-packages/flwr/__init__.py in <module>
     18 from flwr.common.version import package_version as _package_version
     19 
---> 20 from . import client, common, server, simulation
     21 
     22 __all__ = [

/usr/local/lib/python3.12/dist-packages/flwr/server/__init__.py in <module>
     17 
     18 from . import strategy
---> 19 from . import workflow as workflow
     20 from .app import run_driver_api as run_driver_api
     21 from .app import run_fleet_api as run_fleet_api

/usr/local/lib/python3.12/dist-packages/flwr/server/workflow/__init__.py in <module>
     16 
     17 
---> 18 from .default_workflows import DefaultWorkflow
     19 from .secure_aggregation import SecAggPlusWorkflow, SecAggWorkflow
     20 

/usr/local/lib/python3.12/dist-packages/flwr/server/workflow/default_workflows.py in <module>
     35 
     36 from ..client_proxy import ClientProxy
---> 37 from ..compat.app_utils import start_update_client_manager_thread
     38 from ..compat.legacy_context import LegacyContext
     39 from ..driver import Driver

/usr/local/lib/python3.12/dist-packages/flwr/server/compat/__init__.py in <module>
     16 
     17 
---> 18 from .app import start_driver as start_driver
     19 from .legacy_context import LegacyContext as LegacyContext
     20 

/usr/local/lib/python3.12/dist-packages/flwr/server/compat/app.py in <module>
     27 from flwr.server.strategy import Strategy
     28 
---> 29 from ..driver import Driver
     30 from .app_utils import start_update_client_manager_thread
     31 

/usr/local/lib/python3.12/dist-packages/flwr/server/driver/__init__.py in <module>
     18 from .driver import Driver
     19 from .grpc_driver import GrpcDriver
---> 20 from .inmemory_driver import InMemoryDriver
     21 
     22 __all__ = [

/usr/local/lib/python3.12/dist-packages/flwr/server/driver/inmemory_driver.py in <module>
     24 from flwr.common.serde import message_from_taskres, message_to_taskins
     25 from flwr.proto.node_pb2 import Node  # pylint: disable=E0611
---> 26 from flwr.server.superlink.state import StateFactory
     27 
     28 from .driver import Driver

/usr/local/lib/python3.12/dist-packages/flwr/server/superlink/state/__init__.py in <module>
     16 
     17 
---> 18 from .in_memory_state import InMemoryState as InMemoryState
     19 from .sqlite_state import SqliteState as SqliteState
     20 from .state import State as State

/usr/local/lib/python3.12/dist-packages/flwr/server/superlink/state/in_memory_state.py in <module>
     26 from flwr.proto.task_pb2 import TaskIns, TaskRes  # pylint: disable=E0611
     27 from flwr.server.superlink.state.state import State
---> 28 from flwr.server.utils import validate_task_ins_or_res
     29 
     30 from .utils import make_node_unavailable_taskres

/usr/local/lib/python3.12/dist-packages/flwr/server/utils/__init__.py in <module>
     16 
     17 
---> 18 from .tensorboard import tensorboard as tensorboard
     19 from .validator import validate_task_ins_or_res as validate_task_ins_or_res
     20 

/usr/local/lib/python3.12/dist-packages/flwr/server/utils/tensorboard.py in <module>
     27 
     28 try:
---> 29     import tensorflow as TF
     30 except ModuleNotFoundError:
     31     TF = None

/usr/local/lib/python3.12/dist-packages/tensorflow/__init__.py in <module>
     51 from tensorflow._api.v2 import autograph
     52 from tensorflow._api.v2 import bitwise
---> 53 from tensorflow._api.v2 import compat
     54 from tensorflow._api.v2 import config
     55 from tensorflow._api.v2 import data

/usr/local/lib/python3.12/dist-packages/tensorflow/_api/v2/compat/__init__.py in <module>
      6 import sys as _sys
      7 
----> 8 from tensorflow._api.v2.compat import v1
      9 from tensorflow._api.v2.compat import v2
     10 from tensorflow.python.compat.compat import forward_compatibility_horizon # line: 125

/usr/local/lib/python3.12/dist-packages/tensorflow/_api/v2/compat/v1/__init__.py in <module>
     28 from tensorflow._api.v2.compat.v1 import autograph
     29 from tensorflow._api.v2.compat.v1 import bitwise
---> 30 from tensorflow._api.v2.compat.v1 import compat
     31 from tensorflow._api.v2.compat.v1 import config
     32 from tensorflow._api.v2.compat.v1 import data

/usr/local/lib/python3.12/dist-packages/tensorflow/_api/v2/compat/v1/compat/__init__.py in <module>
      6 import sys as _sys
      7 
----> 8 from tensorflow._api.v2.compat.v1.compat import v1
      9 from tensorflow._api.v2.compat.v1.compat import v2
     10 from tensorflow.python.compat.compat import forward_compatibility_horizon # line: 125

/usr/local/lib/python3.12/dist-packages/tensorflow/_api/v2/compat/v1/compat/v1/__init__.py in <module>
     45 from tensorflow._api.v2.compat.v1 import layers
     46 from tensorflow._api.v2.compat.v1 import linalg
---> 47 from tensorflow._api.v2.compat.v1 import lite
     48 from tensorflow._api.v2.compat.v1 import logging
     49 from tensorflow._api.v2.compat.v1 import lookup

/usr/local/lib/python3.12/dist-packages/tensorflow/_api/v2/compat/v1/lite/__init__.py in <module>
      7 
      8 from tensorflow._api.v2.compat.v1.lite import constants
----> 9 from tensorflow._api.v2.compat.v1.lite import experimental
     10 from tensorflow.lite.python.convert import OpsSet # line: 170
     11 from tensorflow.lite.python.convert import toco_convert # line: 1069

/usr/local/lib/python3.12/dist-packages/tensorflow/_api/v2/compat/v1/lite/experimental/__init__.py in <module>
      6 import sys as _sys
      7 
----> 8 from tensorflow._api.v2.compat.v1.lite.experimental import authoring
      9 from tensorflow.lite.python.analyzer import ModelAnalyzer as Analyzer # line: 35
     10 from tensorflow.lite.python.interpreter import OpResolverType # line: 303

/usr/local/lib/python3.12/dist-packages/tensorflow/_api/v2/compat/v1/lite/experimental/authoring/__init__.py in <module>
      6 import sys as _sys
      7 
----> 8 from tensorflow.lite.python.authoring.authoring import compatible # line: 265
      9 
     10 from tensorflow.python.util import module_wrapper as _module_wrapper

/usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/authoring/authoring.py in <module>
     41 
     42 # pylint: disable=g-import-not-at-top
---> 43 from tensorflow.lite.python import convert
     44 from tensorflow.lite.python import lite
     45 from tensorflow.lite.python.metrics import converter_error_data_pb2

/usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py in <module>
     29 from tensorflow.compiler.mlir.quantization.stablehlo import quantization_options_pb2 as quant_opts_pb2
     30 from tensorflow.lite.python import lite_constants
---> 31 from tensorflow.lite.python import util
     32 from tensorflow.lite.python.convert_phase import Component
     33 from tensorflow.lite.python.convert_phase import convert_phase

/usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/util.py in <module>
     53 # pylint: disable=unused-import
     54 try:
---> 55   from jax import xla_computation as _xla_computation
     56 except ImportError:
     57   _xla_computation = None

/usr/local/lib/python3.12/dist-packages/jax/__init__.py in <module>
     35 
     36 # Force early import, allowing use of `jax.core` after importing `jax`.
---> 37 import jax.core as _core
     38 del _core
     39 

/usr/local/lib/python3.12/dist-packages/jax/core.py in <module>
     16 # See PEP 484 & https://github.com/google/jax/issues/7570
     17 
---> 18 from jax._src.core import (
     19   AbstractToken as AbstractToken,
     20   AbstractValue as AbstractValue,

/usr/local/lib/python3.12/dist-packages/jax/_src/core.py in <module>
     45 from jax._src import linear_util as lu
     46 
---> 47 from jax._src import source_info_util
     48 from jax._src.util import (safe_zip, safe_map, curry, tuple_insert,
     49                            tuple_delete, as_hashable_function,

/usr/local/lib/python3.12/dist-packages/jax/_src/source_info_util.py in <module>
     49     # Attach the separator to make sure that .../jax does not end up matching
     50     # .../jax_triton and other packages that might have a jax prefix.
---> 51     os.path.dirname(jax.version.__file__) + os.sep,
     52     # Also exclude stdlib as user frames. In a non-standard Python runtime,
     53     # the following two may be different.

AttributeError: partially initialized module 'jax' has no attribute 'version' (most likely due to a circular import)

# %%
# !pip uninstall -y jax jaxlib

# %%
# !pip install --force-reinstall tensorflow==2.17.0 flwr==1.9.0 numpy==1.26.4 ml-dtypes==0.4.1 protobuf==4.25.3

# %%
from flwr.client import NumPyClient
from flwr.simulation import start_simulation
import tensorflow as tf
import numpy as np

print("Flower client/simulation imports OK")
print("TensorFlow:", tf.__version__)
print("NumPy:", np.__version__)

# %%
from flwr.client import NumPyClient
import tensorflow as tf
import numpy as np

print("NumPyClient import works")
print("TensorFlow:", tf.__version__)
print("NumPy:", np.__version__)

# %%
# !pip install --force-reinstall tensorflow==2.16.1

# %%
import flwr
import torch

print("Flower version:", flwr.__version__)
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

# %%
import torch
import flwr

print("PyTorch:", torch.__version__)
print("Flower:", flwr.__version__)

# %%
# !pip uninstall -y flwr tensorflow
# !pip install flwr-nightly torch torchvision

# %%
# !pip install --force-reinstall flwr==1.9.0 torch torchvision numpy==1.26.4 protobuf==4.25.3 cryptography==45.0.7 click==8.1.7 ml-dtypes==0.4.1

# %%
# !pip install --force-reinstall flwr==1.9.0 cryptography==42.0.8 torch torchvision numpy==1.26.4 protobuf==4.25.3 ml-dtypes==0.4.1 click==8.1.7

# %%
import torch
import flwr

print("PyTorch:", torch.__version__)
print("Flower:", flwr.__version__)

# Simple tensor test
x = torch.tensor([1.0, 2.0, 3.0])
print("Tensor test:", x * 2)

# %%
import flwr as fl
import torch
import torch.nn as nn
import torch.optim as optim

# Simple model
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc = nn.Linear(4, 2)

    def forward(self, x):
        return self.fc(x)

# Dummy dataset
X = torch.randn(20, 4)
y = torch.randint(0, 2, (20,))

class SimpleClient(fl.client.NumPyClient):
    def __init__(self):
        self.model = Net()
        self.optimizer = optim.SGD(self.model.parameters(), lr=0.01)
        self.loss_fn = nn.CrossEntropyLoss()

    def get_parameters(self, config):
        return [val.cpu().numpy() for val in self.model.state_dict().values()]

    def set_parameters(self, parameters):
        state_dict = self.model.state_dict()
        for key, val in zip(state_dict.keys(), parameters):
            state_dict[key] = torch.tensor(val)
        self.model.load_state_dict(state_dict)

    def fit(self, parameters, config):
        self.set_parameters(parameters)
        self.model.train()
        for _ in range(2):
            self.optimizer.zero_grad()
            output = self.model(X)
            loss = self.loss_fn(output, y)
            loss.backward()
            self.optimizer.step()
        return self.get_parameters(config={}), len(X), {}

    def evaluate(self, parameters, config):
        self.set_parameters(parameters)
        self.model.eval()
        with torch.no_grad():
            output = self.model(X)
            loss = self.loss_fn(output, y).item()
            acc = (output.argmax(dim=1) == y).float().mean().item()
        return loss, len(X), {"accuracy": acc}

# Run one round of simulation
fl.simulation.start_simulation(
    client_fn=lambda cid: SimpleClient(),
    num_clients=2,
    num_rounds=1,
)

# %%
import flwr as fl
import torch
import torch.nn as nn
import torch.optim as optim

# 1. Define a simple model
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(4, 10)
        self.fc2 = nn.Linear(10, 2)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        return torch.softmax(self.fc2(x), dim=1)

# 2. Dummy dataset
X = torch.randn(50, 4)   # 50 samples, 4 features
y = torch.randint(0, 2, (50,))  # binary labels

# 3. Define Flower client
class SimpleClient(fl.client.NumPyClient):
    def __init__(self):
        self.model = Net()
        self.optimizer = optim.SGD(self.model.parameters(), lr=0.01)
        self.loss_fn = nn.CrossEntropyLoss()

    def get_parameters(self, config):
        return [val.cpu().numpy() for val in self.model.state_dict().values()]

    def set_parameters(self, parameters):
        state_dict = self.model.state_dict()
        for key, val in zip(state_dict.keys(), parameters):
            state_dict[key] = torch.tensor(val)
        self.model.load_state_dict(state_dict)

    def fit(self, parameters, config):
        self.set_parameters(parameters)
        self.model.train()
        for _ in range(2):  # two mini-epochs
            self.optimizer.zero_grad()
            output = self.model(X)
            loss = self.loss_fn(output, y)
            loss.backward()
            self.optimizer.step()
        return self.get_parameters(config={}), len(X), {}

    def evaluate(self, parameters, config):
        self.set_parameters(parameters)
        self.model.eval()
        with torch.no_grad():
            output = self.model(X)
            loss = self.loss_fn(output, y).item()
            acc = (output.argmax(dim=1) == y).float().mean().item()
        return loss, len(X), {"accuracy": acc}

# 4. Run Flower simulation
config = fl.server.ServerConfig(num_rounds=3)

fl.simulation.start_simulation(
    client_fn=lambda cid: SimpleClient(),
    num_clients=3,
    config=config,
)

# %%
import flwr as fl
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split

# 1. Preprocessing
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

# 2. Load MNIST dataset
trainset = datasets.MNIST("./data", train=True, download=True, transform=transform)
testset = datasets.MNIST("./data", train=False, download=True, transform=transform)

def get_data_loaders():
    train_size = int(0.8 * len(trainset))
    val_size = len(trainset) - train_size
    train_subset, _ = random_split(trainset, [train_size, val_size])
    trainloader = DataLoader(train_subset, batch_size=32, shuffle=True)
    testloader = DataLoader(testset, batch_size=32)
    return trainloader, testloader

# 3. CNN model
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 12 * 12, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = x.view(-1, 64 * 12 * 12)
        x = torch.relu(self.fc1(x))
        return torch.softmax(self.fc2(x), dim=1)

# 4. Flower client with progress prints
class MnistClient(fl.client.NumPyClient):
    def __init__(self, cid):
        self.model = Net()
        self.optimizer = optim.Adam(self.model.parameters(), lr=0.001)
        self.loss_fn = nn.CrossEntropyLoss()
        self.trainloader, self.testloader = get_data_loaders()
        self.cid = cid  # client ID for logging

    def get_parameters(self, config):
        return [val.cpu().numpy() for val in self.model.state_dict().values()]

    def set_parameters(self, parameters):
        state_dict = self.model.state_dict()
        for key, val in zip(state_dict.keys(), parameters):
            state_dict[key] = torch.tensor(val)
        self.model.load_state_dict(state_dict)

    def fit(self, parameters, config):
        self.set_parameters(parameters)
        self.model.train()
        total_loss = 0
        for epoch in range(1):  # one epoch per round
            for data, target in self.trainloader:
                self.optimizer.zero_grad()
                output = self.model(data)
                loss = self.loss_fn(output, target)
                loss.backward()
                self.optimizer.step()
                total_loss += loss.item()
        avg_loss = total_loss / len(self.trainloader)
        print(f"[Client {self.cid}] Training complete - Avg Loss: {avg_loss:.4f}")
        return self.get_parameters(config={}), len(self.trainloader.dataset), {}

    def evaluate(self, parameters, config):
        self.set_parameters(parameters)
        self.model.eval()
        correct, loss = 0, 0.0
        with torch.no_grad():
            for data, target in self.testloader:
                output = self.model(data)
                loss += self.loss_fn(output, target).item()
                pred = output.argmax(dim=1)
                correct += pred.eq(target).sum().item()
        accuracy = correct / len(self.testloader.dataset)
        avg_loss = loss / len(self.testloader)
        print(f"[Client {self.cid}] Evaluation - Loss: {avg_loss:.4f}, Accuracy: {accuracy:.4f}")
        return avg_loss, len(self.testloader.dataset), {"accuracy": accuracy}

# 5. Run Flower simulation with progress prints
config = fl.server.ServerConfig(num_rounds=3)

fl.simulation.start_simulation(
    client_fn=lambda cid: MnistClient(cid),
    num_clients=3,
    config=config,
)

# %%
# !pip uninstall -y torchvision

# %%
# !pip install torchvision==0.19.1

# %%
# !pip install --force-reinstall torch==2.8.0 torchvision==0.19.1 torchaudio==2.8.0

# %%
# !pip install --force-reinstall torch==2.8.0 torchvision==0.24.1 torchaudio==2.8.0

# %%
# !pip install --force-reinstall torch==2.9.1 torchvision==0.24.1 torchaudio==2.9.1

# %%
# !pip install --force-reinstall numpy==1.26.4

# %%
import torch, torchvision, torchaudio, numpy

print("Torch:", torch.__version__)
print("TorchVision:", torchvision.__version__)
print("Torchaudio:", torchaudio.__version__)
print("NumPy:", numpy.__version__)

# %%
# !pip install --force-reinstall torchvision==0.24.1 torch==2.9.1 torchaudio==2.9.1

# %%
import  numpy


print("NumPy:", numpy.__version__)

# %%
pip install --force-reinstall numpy==1.26.4

# %%
import torch, torchvision, torchaudio, numpy

print("Torch:", torch.__version__)
print("TorchVision:", torchvision.__version__)
print("Torchaudio:", torchaudio.__version__)
print("NumPy:", numpy.__version__)

# %%
pip install --force-reinstall numpy==1.26.4

# %%
import torch, torchvision, torchaudio, numpy
print("Torch:", torch.__version__)
print("TorchVision:", torchvision.__version__)
print("Torchaudio:", torchaudio.__version__)
print("NumPy:", numpy.__version__)

# %%
pip uninstall -y numpy

# %%
pip install numpy==1.26.4

# %%
import numpy, torch, torchvision, torchaudio
print("NumPy:", numpy.__version__)
print("Torch:", torch.__version__)
print("TorchVision:", torchvision.__version__)
print("Torchaudio:", torchaudio.__version__)
# Out:
# NumPy: 2.0.2
# Torch: 2.8.0+cu126
# TorchVision: 0.23.0+cu126
# Torchaudio: 2.8.0+cu126

# %%
# !pip install --force-reinstall numpy==1.26.4
import numpy
print("NumPy now pinned to:", numpy.__version__)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 83.2 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.26.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# ...

# %%
# !pip install --force-reinstall numpy==1.26.4
import numpy
print("NumPy now pinned to:", numpy.__version__)
# Out:
# ...
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.26.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# ...

# %%
# !pip install --force-reinstall numpy==1.26.4
import importlib, numpy
importlib.reload(numpy)   # force Python to reload the downgraded NumPy
print("NumPy now pinned to:", numpy.__version__)
# Out:
# ...
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.26.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# ...

# %%
# Force reinstall NumPy to the correct version
# !pip install --force-reinstall numpy==1.26.4

# Reload NumPy so Python uses the downgraded version immediately
import importlib, numpy
importlib.reload(numpy)

# Check all critical versions
import torch, torchvision, torchaudio
print("NumPy:", numpy.__version__)
print("Torch:", torch.__version__)
print("TorchVision:", torchvision.__version__)
print("Torchaudio:", torchaudio.__version__)
# Out:
# ...
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.26.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# ...

# %%
# !pip install --force-reinstall numpy==1.26.4

import sys
import importlib

# Force Python to reload the downgraded NumPy wheel
if "numpy" in sys.modules:
    del sys.modules["numpy"]

import numpy
print("NumPy now pinned to:", numpy.__version__)
# Out:
# ...
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.26.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# ...

# %%
# !pip install --force-reinstall numpy==1.26.4

import sys
if "numpy" in sys.modules:
    del sys.modules["numpy"]

import numpy
print("NumPy now pinned to:", numpy.__version__)
# Out:
# ...
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.26.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# ...

# %%
# --- Setup cell: pin NumPy before Flower ---
# !pip install --force-reinstall numpy==1.26.4

import sys
if "numpy" in sys.modules:
    del sys.modules["numpy"]

import numpy, torch, torchvision, torchaudio
print("NumPy:", numpy.__version__)
print("Torch:", torch.__version__)
print("TorchVision:", torchvision.__version__)
print("Torchaudio:", torchaudio.__version__)

# --- Week 4 Federated MNIST Simulation ---
import flwr as fl
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split

# Device helper: GPU if available, else CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# 1. Preprocessing
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

# 2. Load MNIST dataset
trainset = datasets.MNIST("./data", train=True, download=True, transform=transform)
testset = datasets.MNIST("./data", train=False, download=True, transform=transform)

def get_data_loaders():
    train_size = int(0.8 * len(trainset))
    val_size = len(trainset) - train_size
    train_subset, _ = random_split(trainset, [train_size, val_size])
    trainloader = DataLoader(train_subset, batch_size=32, shuffle=True)
    testloader = DataLoader(testset, batch_size=32)
    return trainloader, testloader

# 3. CNN model
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 12 * 12, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = x.view(-1, 64 * 12 * 12)
        x = torch.relu(self.fc1(x))
        return torch.softmax(self.fc2(x), dim=1)

# 4. Flower client
class MnistClient(fl.client.NumPyClient):
    def __init__(self, cid):
        self.model = Net().to(device)
        self.optimizer = optim.Adam(self.model.parameters(), lr=0.001)
        self.loss_fn = nn.CrossEntropyLoss()
        self.trainloader, self.testloader = get_data_loaders()
        self.cid = cid

    def get_parameters(self, config):
        return [val.cpu().numpy() for val in self.model.state_dict().values()]

    def set_parameters(self, parameters):
        state_dict = self.model.state_dict()
        for key, val in zip(state_dict.keys(), parameters):
            state_dict[key] = torch.tensor(val)
        self.model.load_state_dict(state_dict)

    def fit(self, parameters, config):
        self.set_parameters(parameters)
        self.model.train()
        total_loss = 0
        for data, target in self.trainloader:
            data, target = data.to(device), target.to(device)
            self.optimizer.zero_grad()
            output = self.model(data)
            loss = self.loss_fn(output, target)
            loss.backward()
            self.optimizer.step()
            total_loss += loss.item()
        avg_loss = total_loss / len(self.trainloader)
        print(f"[Client {self.cid}] Training complete - Avg Loss: {avg_loss:.4f}")
        return self.get_parameters(config={}), len(self.trainloader.dataset), {}

    def evaluate(self, parameters, config):
        self.set_parameters(parameters)
        self.model.eval()
        correct, loss = 0, 0.0
        with torch.no_grad():
            for data, target in self.testloader:
                data, target = data.to(device), target.to(device)
                output = self.model(data)
                loss += self.loss_fn(output, target).item()
                pred = output.argmax(dim=1)
                correct += pred.eq(target).sum().item()
        accuracy = correct / len(self.testloader.dataset)
        avg_loss = loss / len(self.testloader)
        print(f"[Client {self.cid}] Evaluation - Loss: {avg_loss:.4f}, Accuracy: {accuracy:.4f}")
        return avg_loss, len(self.testloader.dataset), {"accuracy": accuracy}

# 5. Run Flower simulation
config = fl.server.ServerConfig(num_rounds=3)

fl.simulation.start_simulation(
    client_fn=lambda cid: MnistClient(cid),
    num_clients=3,
    config=config,
)
# Out:
# ...
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.26.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# ...

# %%
# !pip install flwr==1.9.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.7/364.7 kB 16.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 91.6 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 19.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.7/251.7 kB 18.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.4/242.4 kB 15.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typer
#     Found existing installation: typer 0.20.0
#     Uninstalling typer-0.20.0:
#       Successfully uninstalled typer-0.20.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
#   Attempting uninstall: rich
#     Found existing installation: rich 14.2.0
#     Uninstalling rich-14.2.0:
#       Successfully uninstalled rich-14.2.0
# ...

# %%
import flwr
print("Flower version:", flwr.__version__)
# Out:
# 2026-01-15 14:51:06.787945: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768488666.983211      99 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768488667.040840      99 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768488667.492882      99 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !pip uninstall -y flwr tensorflow ml-dtypes
# !pip install flwr[simulation]==1.9.0
# Out:
# Found existing installation: flwr 1.9.0
# Uninstalling flwr-1.9.0:
#   Successfully uninstalled flwr-1.9.0
# Found existing installation: tensorflow 2.19.0
# Uninstalling tensorflow-2.19.0:
#   Successfully uninstalled tensorflow-2.19.0
# Found existing installation: ml_dtypes 0.5.3
# Uninstalling ml_dtypes-0.5.3:
#   Successfully uninstalled ml_dtypes-0.5.3
# ...
#   Using cached flwr-1.9.0-py3-none-any.whl.metadata (15 kB)
# ...
# Using cached flwr-1.9.0-py3-none-any.whl (364 kB)
# ...

# %%
import flwr
print("Flower version:", flwr.__version__)
# Out:
# Flower version: 1.9.0
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
# --- Imports ---
import flwr as fl
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split
import logging
logging.getLogger("ray").setLevel(logging.ERROR)

# Device helper
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# 1. Preprocessing
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

# 2. Load MNIST dataset
trainset = datasets.MNIST("./data", train=True, download=True, transform=transform)
testset = datasets.MNIST("./data", train=False, download=True, transform=transform)

def get_data_loaders():
    train_size = int(0.8 * len(trainset))
    val_size = len(trainset) - train_size
    train_subset, _ = random_split(trainset, [train_size, val_size])
    trainloader = DataLoader(train_subset, batch_size=32, shuffle=True)
    testloader = DataLoader(testset, batch_size=32)
    return trainloader, testloader

# 3. CNN model
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 12 * 12, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = x.view(-1, 64 * 12 * 12)
        x = torch.relu(self.fc1(x))
        return torch.softmax(self.fc2(x), dim=1)

# 4. Flower client
class MnistClient(fl.client.NumPyClient):
    def __init__(self, cid):
        self.model = Net().to(device)
        self.optimizer = optim.Adam(self.model.parameters(), lr=0.001)
        self.loss_fn = nn.CrossEntropyLoss()
        self.trainloader, self.testloader = get_data_loaders()
        self.cid = cid

    def get_parameters(self, config):
        return [val.cpu().numpy() for val in self.model.state_dict().values()]

    def set_parameters(self, parameters):
        state_dict = self.model.state_dict()
        for key, val in zip(state_dict.keys(), parameters):
            state_dict[key] = torch.tensor(val)
        self.model.load_state_dict(state_dict)

    def fit(self, parameters, config):
        self.set_parameters(parameters)
        self.model.train()
        for data, target in self.trainloader:
            data, target = data.to(device), target.to(device)
            self.optimizer.zero_grad()
            output = self.model(data)
            loss = self.loss_fn(output, target)
            loss.backward()
            self.optimizer.step()
        return self.get_parameters(config={}), len(self.trainloader.dataset), {}

    def evaluate(self, parameters, config):
        self.set_parameters(parameters)
        self.model.eval()
        correct, loss = 0, 0.0
        with torch.no_grad():
            for data, target in self.testloader:
                data, target = data.to(device), target.to(device)
                output = self.model(data)
                loss += self.loss_fn(output, target).item()
                pred = output.argmax(dim=1)
                correct += pred.eq(target).sum().item()
        accuracy = correct / len(self.testloader.dataset)
        avg_loss = loss / len(self.testloader)
        return avg_loss, len(self.testloader.dataset), {"accuracy": accuracy}

# 5. Custom strategy for global round summary
class GlobalSummaryStrategy(fl.server.strategy.FedAvg):
    def aggregate_evaluate(self, rnd, results, failures):
        if results:
            accuracies = [res.metrics["accuracy"] for _, res in results]
            avg_acc = sum(accuracies) / len(accuracies)
            print(f"Round {rnd}: Global Accuracy = {avg_acc:.4f}")
        return super().aggregate_evaluate(rnd, results, failures)

# 6. Run Flower simulation
config = fl.server.ServerConfig(num_rounds=3)

fl.simulation.start_simulation(
    client_fn=lambda cid: MnistClient(cid),
    num_clients=3,
    config=config,
    strategy=GlobalSummaryStrategy(),
)
# Out:
# INFO :      Starting Flower simulation, config: num_rounds=3, no round_timeout
# Using device: cpu
# (ClientAppActor pid=359) [2026-01-15 14:55:44,803 E 359 524] core_worker_process.cc:837: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14 [repeated 3x across cluster]
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# 2026-01-15 14:59:05,028	INFO worker.py:2023 -- Started a local Ray instance.
# ...

# %%
pip install numpy==1.26.4
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 68.9 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.26.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# ...

# %%
# --- Suppress warnings and Ray logs for clean output ---
import warnings, logging
warnings.filterwarnings("ignore", category=DeprecationWarning)
logging.getLogger("ray").setLevel(logging.ERROR)

# --- NumPy patch for Flower compatibility ---
import numpy as np
import numpy.lib.npyio as npyio
np.load = npyio.load   # ✅ re-expose np.load for Flower

# --- Imports ---
import flwr as fl
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split

# Device helper
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# 1. Preprocessing
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

# 2. Load MNIST dataset
trainset = datasets.MNIST("./data", train=True, download=True, transform=transform)
testset = datasets.MNIST("./data", train=False, download=True, transform=transform)

def get_data_loaders():
    train_size = int(0.8 * len(trainset))
    val_size = len(trainset) - train_size
    train_subset, _ = random_split(trainset, [train_size, val_size])
    trainloader = DataLoader(train_subset, batch_size=32, shuffle=True)
    testloader = DataLoader(testset, batch_size=32)
    return trainloader, testloader

# 3. Corrected CNN model
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 128)  # ✅ corrected flatten size
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))  # 28→26→13
        x = self.pool(torch.relu(self.conv2(x)))  # 13→11→5
        x = x.view(-1, 64 * 5 * 5)                # ✅ corrected flatten
        x = torch.relu(self.fc1(x))
        return torch.softmax(self.fc2(x), dim=1)

# 4. Flower client
class MnistClient(fl.client.NumPyClient):
    def __init__(self, cid):
        self.model = Net().to(device)
        self.optimizer = optim.Adam(self.model.parameters(), lr=0.001)
        self.loss_fn = nn.CrossEntropyLoss()
        self.trainloader, self.testloader = get_data_loaders()
        self.cid = cid

    def get_parameters(self, config):
        return [val.cpu().numpy() for val in self.model.state_dict().values()]

    def set_parameters(self, parameters):
        state_dict = self.model.state_dict()
        for key, val in zip(state_dict.keys(), parameters):
            state_dict[key] = torch.tensor(val)
        self.model.load_state_dict(state_dict)

    def fit(self, parameters, config):
        self.set_parameters(parameters)
        self.model.train()
        for data, target in self.trainloader:
            data, target = data.to(device), target.to(device)
            self.optimizer.zero_grad()
            output = self.model(data)
            loss = self.loss_fn(output, target)
            loss.backward()
            self.optimizer.step()
        return self.get_parameters(config={}), len(self.trainloader.dataset), {}

    def evaluate(self, parameters, config):
        self.set_parameters(parameters)
        self.model.eval()
        correct, loss = 0, 0.0
        with torch.no_grad():
            for data, target in self.testloader:
                data, target = data.to(device), target.to(device)
                output = self.model(data)
                loss += self.loss_fn(output, target).item()
                pred = output.argmax(dim=1)
                correct += pred.eq(target).sum().item()
        accuracy = correct / len(self.testloader.dataset)
        avg_loss = loss / len(self.testloader)
        return avg_loss, len(self.testloader.dataset), {"accuracy": accuracy}

# 5. Custom strategy for global round summary
class GlobalSummaryStrategy(fl.server.strategy.FedAvg):
    def aggregate_evaluate(self, rnd, results, failures):
        if results:
            accuracies = [res.metrics["accuracy"] for _, res in results]
            avg_acc = sum(accuracies) / len(accuracies)
            print(f"Round {rnd}: Global Accuracy = {avg_acc:.4f}")
        return super().aggregate_evaluate(rnd, results, failures)

# 6. Run Flower simulation
config = fl.server.ServerConfig(num_rounds=3)

fl.simulation.start_simulation(
    client_fn=lambda cid: MnistClient(cid).to_client(),  # ✅ .to_client() fix
    num_clients=3,
    config=config,
    strategy=GlobalSummaryStrategy(),
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_99/3827882060.py in <cell line: 0>()
#       7 import numpy as np
#       8 import numpy.lib.npyio as npyio
# ----> 9 np.load = npyio.load   # ✅ re-expose np.load for Flower
#      10
#      11 # --- Imports ---
#
# AttributeError: module 'numpy.lib.npyio' has no attribute 'load'

# %%
# --- Suppress warnings and Ray logs for clean output ---
import warnings, logging
warnings.filterwarnings("ignore", category=DeprecationWarning)
logging.getLogger("ray").setLevel(logging.ERROR)

# --- NumPy patch for Flower compatibility in Kaggle ---
import numpy as np, io
def safe_load(bytes_io, allow_pickle=False):
    bytes_io.seek(0)
    return np.frombuffer(bytes_io.read(), dtype=np.float32)
np.load = safe_load

# --- Imports ---
import flwr as fl
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split

# Device helper
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# 1. Preprocessing
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

# 2. Load MNIST dataset
trainset = datasets.MNIST("./data", train=True, download=True, transform=transform)
testset = datasets.MNIST("./data", train=False, download=True, transform=transform)

def get_data_loaders():
    train_size = int(0.8 * len(trainset))
    val_size = len(trainset) - train_size
    train_subset, _ = random_split(trainset, [train_size, val_size])
    trainloader = DataLoader(train_subset, batch_size=32, shuffle=True)
    testloader = DataLoader(testset, batch_size=32)
    return trainloader, testloader

# 3. Corrected CNN model
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 128)  # ✅ corrected flatten size
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))  # 28→26→13
        x = self.pool(torch.relu(self.conv2(x)))  # 13→11→5
        x = x.view(-1, 64 * 5 * 5)                # ✅ corrected flatten
        x = torch.relu(self.fc1(x))
        return torch.softmax(self.fc2(x), dim=1)

# 4. Flower client
class MnistClient(fl.client.NumPyClient):
    def __init__(self, cid):
        self.model = Net().to(device)
        self.optimizer = optim.Adam(self.model.parameters(), lr=0.001)
        self.loss_fn = nn.CrossEntropyLoss()
        self.trainloader, self.testloader = get_data_loaders()
        self.cid = cid

    def get_parameters(self, config):
        return [val.cpu().numpy() for val in self.model.state_dict().values()]

    def set_parameters(self, parameters):
        state_dict = self.model.state_dict()
        for key, val in zip(state_dict.keys(), parameters):
            state_dict[key] = torch.tensor(val)
        self.model.load_state_dict(state_dict)

    def fit(self, parameters, config):
        self.set_parameters(parameters)
        self.model.train()
        for data, target in self.trainloader:
            data, target = data.to(device), target.to(device)
            self.optimizer.zero_grad()
            output = self.model(data)
            loss = self.loss_fn(output, target)
            loss.backward()
            self.optimizer.step()
        return self.get_parameters(config={}), len(self.trainloader.dataset), {}

    def evaluate(self, parameters, config):
        self.set_parameters(parameters)
        self.model.eval()
        correct, loss = 0, 0.0
        with torch.no_grad():
            for data, target in self.testloader:
                data, target = data.to(device), target.to(device)
                output = self.model(data)
                loss += self.loss_fn(output, target).item()
                pred = output.argmax(dim=1)
                correct += pred.eq(target).sum().item()
        accuracy = correct / len(self.testloader.dataset)
        avg_loss = loss / len(self.testloader)
        return avg_loss, len(self.testloader.dataset), {"accuracy": accuracy}

# 5. Custom strategy for global round summary
class GlobalSummaryStrategy(fl.server.strategy.FedAvg):
    def aggregate_evaluate(self, rnd, results, failures):
        if results:
            accuracies = [res.metrics["accuracy"] for _, res in results]
            avg_acc = sum(accuracies) / len(accuracies)
            print(f"Round {rnd}: Global Accuracy = {avg_acc:.4f}")
        return super().aggregate_evaluate(rnd, results, failures)

# 6. Run Flower simulation
config = fl.server.ServerConfig(num_rounds=3)

fl.simulation.start_simulation(
    client_fn=lambda cid: MnistClient(cid).to_client(),  # ✅ .to_client() fix
    num_clients=3,
    config=config,
    strategy=GlobalSummaryStrategy(),
)
# Out:
# INFO :      Starting Flower simulation, config: num_rounds=3, no round_timeout
# Using device: cpu
# 2026-01-15 15:16:24,715	INFO worker.py:2023 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 4.0, 'memory': 21475133031.0, 'node:172.19.2.2': 1.0, 'node:__internal_head__': 1.0, 'object_store_memory': 9203628441.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      No `client_resources` specified. Using minimal resources for clients.
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0.0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# INFO :      Received initial parameters from one random client
# INFO :      Evaluating initial global parameters
# INFO :
# INFO :      [ROUND 1]
# ...

# %%
# --- Suppress warnings and Ray logs for clean output ---
import warnings, logging
warnings.filterwarnings("ignore", category=DeprecationWarning)
logging.getLogger("ray").setLevel(logging.ERROR)

# --- NumPy patch for Flower compatibility in Kaggle ---
import numpy as np, io
import numpy.lib.format as npformat

def safe_load(bytes_io, allow_pickle=False):
    bytes_io.seek(0)
    return npformat.read_array(bytes_io, allow_pickle=allow_pickle)

def safe_save(bytes_io, arr, allow_pickle=False):
    npformat.write_array(bytes_io, arr, allow_pickle=allow_pickle)

np.load = safe_load
np.save = safe_save

# --- Imports ---
import flwr as fl
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split

# Device helper
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# 1. Preprocessing
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

# 2. Load MNIST dataset
trainset = datasets.MNIST("./data", train=True, download=True, transform=transform)
testset = datasets.MNIST("./data", train=False, download=True, transform=transform)

def get_data_loaders():
    train_size = int(0.8 * len(trainset))
    val_size = len(trainset) - train_size
    train_subset, _ = random_split(trainset, [train_size, val_size])
    trainloader = DataLoader(train_subset, batch_size=32, shuffle=True)
    testloader = DataLoader(testset, batch_size=32)
    return trainloader, testloader

# 3. Corrected CNN model
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 128)  # ✅ corrected flatten size
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))  # 28→26→13
        x = self.pool(torch.relu(self.conv2(x)))  # 13→11→5
        x = x.view(-1, 64 * 5 * 5)                # ✅ corrected flatten
        x = torch.relu(self.fc1(x))
        return torch.softmax(self.fc2(x), dim=1)

# 4. Flower client
class MnistClient(fl.client.NumPyClient):
    def __init__(self, cid):
        self.model = Net().to(device)
        self.optimizer = optim.Adam(self.model.parameters(), lr=0.001)
        self.loss_fn = nn.CrossEntropyLoss()
        self.trainloader, self.testloader = get_data_loaders()
        self.cid = cid

    def get_parameters(self, config):
        return [val.cpu().numpy() for val in self.model.state_dict().values()]

    def set_parameters(self, parameters):
        state_dict = self.model.state_dict()
        for key, val in zip(state_dict.keys(), parameters):
            state_dict[key] = torch.tensor(val)
        self.model.load_state_dict(state_dict)

    def fit(self, parameters, config):
        self.set_parameters(parameters)
        self.model.train()
        for data, target in self.trainloader:
            data, target = data.to(device), target.to(device)
            self.optimizer.zero_grad()
            output = self.model(data)
            loss = self.loss_fn(output, target)
            loss.backward()
            self.optimizer.step()
        return self.get_parameters(config={}), len(self.trainloader.dataset), {}

    def evaluate(self, parameters, config):
        self.set_parameters(parameters)
        self.model.eval()
        correct, loss = 0, 0.0
        with torch.no_grad():
            for data, target in self.testloader:
                data, target = data.to(device), target.to(device)
                output = self.model(data)
                loss += self.loss_fn(output, target).item()
                pred = output.argmax(dim=1)
                correct += pred.eq(target).sum().item()
        accuracy = correct / len(self.testloader.dataset)
        avg_loss = loss / len(self.testloader)
        return avg_loss, len(self.testloader.dataset), {"accuracy": accuracy}

# 5. Custom strategy for global round summary
class GlobalSummaryStrategy(fl.server.strategy.FedAvg):
    def aggregate_evaluate(self, rnd, results, failures):
        if results:
            accuracies = [res.metrics["accuracy"] for _, res in results]
            avg_acc = sum(accuracies) / len(accuracies)
            print(f"Round {rnd}: Global Accuracy = {avg_acc:.4f}")
        return super().aggregate_evaluate(rnd, results, failures)

# 6. Run Flower simulation
config = fl.server.ServerConfig(num_rounds=3)

fl.simulation.start_simulation(
    client_fn=lambda cid: MnistClient(cid).to_client(),  # ✅ .to_client() fix
    num_clients=3,
    config=config,
    strategy=GlobalSummaryStrategy(),
)
# Out:
# INFO :      Starting Flower simulation, config: num_rounds=3, no round_timeout
# Using device: cpu
# 2026-01-15 15:19:48,995	INFO worker.py:2023 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 4.0, 'memory': 21474846311.0, 'node:__internal_head__': 1.0, 'object_store_memory': 9203505561.0, 'node:172.19.2.2': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      No `client_resources` specified. Using minimal resources for clients.
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0.0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# INFO :      Received initial parameters from one random client
# INFO :      Evaluating initial global parameters
# INFO :
# INFO :      [ROUND 1]
# ...

# %%
# --- Suppress warnings and Ray logs for clean output ---
import warnings, logging
warnings.filterwarnings("ignore", category=DeprecationWarning)
logging.getLogger("ray").setLevel(logging.ERROR)

# --- NumPy patch for Flower compatibility in Kaggle ---
import numpy as np, io
import numpy.lib.format as npformat

def safe_load(bytes_io, allow_pickle=False):
    bytes_io.seek(0)
    return npformat.read_array(bytes_io, allow_pickle=allow_pickle)

def safe_save(bytes_io, arr, allow_pickle=False):
    npformat.write_array(bytes_io, arr, allow_pickle=allow_pickle)

np.load = safe_load
np.save = safe_save

# --- Imports ---
import flwr as fl
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Subset

# Device helper
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# 1. Preprocessing
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

# 2. Load MNIST dataset
trainset = datasets.MNIST("./data", train=True, download=True, transform=transform)
testset = datasets.MNIST("./data", train=False, download=True, transform=transform)

# --- Non-IID split function ---
def get_non_iid_loader(digit_range):
    """Return DataLoader for a specific digit range."""
    indices = [i for i, (_, label) in enumerate(trainset) if label in digit_range]
    subset = Subset(trainset, indices)
    loader = DataLoader(subset, batch_size=32, shuffle=True)
    return loader

def get_test_loader():
    return DataLoader(testset, batch_size=32)

# 3. Corrected CNN model
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 128)  # corrected flatten size
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))  # 28→26→13
        x = self.pool(torch.relu(self.conv2(x)))  # 13→11→5
        x = x.view(-1, 64 * 5 * 5)
        x = torch.relu(self.fc1(x))
        return torch.softmax(self.fc2(x), dim=1)

# 4. Flower client with non-IID data
class MnistClient(fl.client.NumPyClient):
    def __init__(self, cid):
        self.model = Net().to(device)
        self.optimizer = optim.Adam(self.model.parameters(), lr=0.001)
        self.loss_fn = nn.CrossEntropyLoss()
        # Assign digit ranges per client
        if cid == "0":
            self.trainloader = get_non_iid_loader(range(0,4))   # digits 0–3
        elif cid == "1":
            self.trainloader = get_non_iid_loader(range(4,7))   # digits 4–6
        else:
            self.trainloader = get_non_iid_loader(range(7,10))  # digits 7–9
        self.testloader = get_test_loader()
        self.cid = cid

    def get_parameters(self, config):
        return [val.cpu().numpy() for val in self.model.state_dict().values()]

    def set_parameters(self, parameters):
        state_dict = self.model.state_dict()
        for key, val in zip(state_dict.keys(), parameters):
            state_dict[key] = torch.tensor(val)
        self.model.load_state_dict(state_dict)

    def fit(self, parameters, config):
        self.set_parameters(parameters)
        self.model.train()
        for data, target in self.trainloader:
            data, target = data.to(device), target.to(device)
            self.optimizer.zero_grad()
            output = self.model(data)
            loss = self.loss_fn(output, target)
            loss.backward()
            self.optimizer.step()
        return self.get_parameters(config={}), len(self.trainloader.dataset), {}

    def evaluate(self, parameters, config):
        self.set_parameters(parameters)
        self.model.eval()
        correct, loss = 0, 0.0
        with torch.no_grad():
            for data, target in self.testloader:
                data, target = data.to(device), target.to(device)
                output = self.model(data)
                loss += self.loss_fn(output, target).item()
                pred = output.argmax(dim=1)
                correct += pred.eq(target).sum().item()
        accuracy = correct / len(self.testloader.dataset)
        avg_loss = loss / len(self.testloader)
        return avg_loss, len(self.testloader.dataset), {"accuracy": accuracy}

# 5. Custom strategy for global round summary
class GlobalSummaryStrategy(fl.server.strategy.FedAvg):
    def aggregate_evaluate(self, rnd, results, failures):
        if results:
            accuracies = [res.metrics["accuracy"] for _, res in results]
            avg_acc = sum(accuracies) / len(accuracies)
            print(f"Round {rnd}: Global Accuracy = {avg_acc:.4f}")
        return super().aggregate_evaluate(rnd, results, failures)

# 6. Run Flower simulation
config = fl.server.ServerConfig(num_rounds=10)  # run 5 rounds

fl.simulation.start_simulation(
    client_fn=lambda cid: MnistClient(cid).to_client(),
    num_clients=3,
    config=config,
    strategy=GlobalSummaryStrategy(),
)
# Out:
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# Using device: cpu
# 2026-01-15 15:42:28,252	INFO worker.py:2023 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 4.0, 'object_store_memory': 9201809817.0, 'node:172.19.2.2': 1.0, 'memory': 21470889575.0, 'node:__internal_head__': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      No `client_resources` specified. Using minimal resources for clients.
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0.0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 4 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# INFO :      Received initial parameters from one random client
# INFO :      Evaluating initial global parameters
# INFO :
# INFO :      [ROUND 1]
# ...
